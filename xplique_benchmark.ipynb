# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielkasmi/xplique/blob/master/xplique_benchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Xplique benchmark

# %%
# !pip install xplique

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# load, prepare and show the sample
# !wget -q 'https://unsplash.com/photos/XOxsVJmCyxk/download?force=true&w=640' -O 'fox.jpg'

x = np.expand_dims(tf.keras.preprocessing.image.load_img("fox.jpg", target_size=(299, 299)), 0)
x = np.array(x, dtype=np.float32) / 255.0

y = np.expand_dims(tf.keras.utils.to_categorical(277, 1000), 0)

plt.rcParams["figure.figsize"] = [12.5, 5]
plt.imshow(x[0])
plt.axis('off')
plt.show()

# %%
model = tf.keras.applications.InceptionV3()
# Out:
# ...
# 96112376/96112376 [==============================] - 0s 0us/step

# %%
from xplique.attributions import GradCAM, Sobol
from xplique.metrics import Deletion

# load images, labels and model
# ...

grad_cam = GradCAM(model)
explanations = explainer(x, y)
metric = Deletion(model, x, y)

score_grad_cam = metric(explanations)

# %%
score_grad_cam
# Out:
# 0.09159211814403534
